# %% [markdown]
# <a href="https://colab.research.google.com/github/gav-ip/cse176-fall-proj/blob/part2/xgboost_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**XG Boost**

# %%
# skip
# %pip install -r ../requirements.txt

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from scipy.io import loadmat
import seaborn as sns
import numpy as np
import pandas as pd
import xgboost as xgb

# %% [markdown]
# #**LOAD MNIST**

# %%
mnist = loadmat('./MNIST.mat')

# Extract data
X_train_full = mnist['train_fea']
y_train_full = mnist['train_gnd'].ravel()
X_test = mnist['test_fea']
y_test = mnist['test_gnd'].ravel()

# Split training into train and validation (55k train, 5k val)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=5000, random_state=42)

# shift labels to 0-9
y_train = y_train - 1
y_val = y_val - 1
y_test = y_test - 1

print(f"Training set: {X_train.shape}, {y_train.shape}")
print(f"Validation set: {X_val.shape}, {y_val.shape}")
print(f"Test set: {X_test.shape}, {y_test.shape}")
# Out:
# Training set: (55000, 784), (55000,)
# Validation set: (5000, 784), (5000,)
# Test set: (10000, 784), (10000,)

# %% [markdown]
# #**MODEL FITTING AND EARLY STOPPING**
# *- ran on Google Colab T4 GPU*

# %%
# Early stopping callback to prevent overfitting
early_stop = xgb.callback.EarlyStopping(
    rounds=20,
    metric_name='mlogloss',
    data_name='validation_0',
    save_best=True,
    min_delta=1e-3    # (default 1e-2) Improvement threshold for continued training, decreasing to prevent premature stopping or increase to mitigate overfitting
)
# Use "hist" for constructing the trees, with early stopping enabled.
clf = xgb.XGBClassifier(
    tree_method="hist",
    n_estimators=2000,
    eval_metric="mlogloss",
    device = 'cuda',
    max_depths = 5,   # Balanced value of ranges of max_depth of the decision tree to prevent overfitting
    callbacks=[early_stop]
)

# %% [markdown]
# ## Fitting model

# %%
# Fitting model using train and validation sets
clf.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    verbose=True  # Set to True if you want to see the log stream for training (validation_0) and validation (validation_1)
)

results = clf.evals_result()

epochs = len(results['validation_0']['mlogloss'])
x_axis = range(0, epochs)
print("done fitting")
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/callback.py:386: UserWarning: [07:25:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "max_depths" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [0]	validation_0-mlogloss:1.36449	validation_1-mlogloss:1.38829
# [1]	validation_0-mlogloss:1.02956	validation_1-mlogloss:1.06412
# [2]	validation_0-mlogloss:0.81324	validation_1-mlogloss:0.85551
# [3]	validation_0-mlogloss:0.65526	validation_1-mlogloss:0.70079
# [4]	validation_0-mlogloss:0.54020	validation_1-mlogloss:0.58889
# [5]	validation_0-mlogloss:0.45105	validation_1-mlogloss:0.50379
# [6]	validation_0-mlogloss:0.38209	validation_1-mlogloss:0.43763
# [7]	validation_0-mlogloss:0.32679	validation_1-mlogloss:0.38517
# [8]	validation_0-mlogloss:0.28235	validation_1-mlogloss:0.34211
# [9]	validation_0-mlogloss:0.24611	validation_1-mlogloss:0.30627
# [10]	validation_0-mlogloss:0.21612	validation_1-mlogloss:0.27760
# [11]	validation_0-mlogloss:0.19138	validation_1-mlogloss:0.25395
# [12]	validation_0-mlogloss:0.16980	validation_1-mlogloss:0.23396
# [13]	validation_0-mlogloss:0.15294	validation_1-mlogloss:0.21826
# [14]	validation_0-mlogloss:0.13857	validation_1-mlogloss:0.20401
# [15]	validation_0-mlogloss:0.12554	validation_1-mlogloss:0.19183
# [16]	validation_0-mlogloss:0.11388	validation_1-mlogloss:0.18088
# [17]	validation_0-mlogloss:0.10468	validation_1-mlogloss:0.17258
# [18]	validation_0-mlogloss:0.09563	validation_1-mlogloss:0.16431
# [19]	validation_0-mlogloss:0.08776	validation_1-mlogloss:0.15679
# [20]	validation_0-mlogloss:0.08115	validation_1-mlogloss:0.15103
# [21]	validation_0-mlogloss:0.07488	validation_1-mlogloss:0.14501
# [22]	validation_0-mlogloss:0.06976	validation_1-mlogloss:0.14004
# [23]	validation_0-mlogloss:0.06459	validation_1-mlogloss:0.13494
# [24]	validation_0-mlogloss:0.05989	validation_1-mlogloss:0.13069
# [25]	validation_0-mlogloss:0.05530	validation_1-mlogloss:0.12698
# [26]	validation_0-mlogloss:0.05089	validation_1-mlogloss:0.12351
# [27]	validation_0-mlogloss:0.04719	validation_1-mlogloss:0.11991
# [28]	validation_0-mlogloss:0.04422	validation_1-mlogloss:0.11707
# [29]	validation_0-mlogloss:0.04107	validation_1-mlogloss:0.11426
# [30]	validation_0-mlogloss:0.03856	validation_1-mlogloss:0.11135
# [31]	validation_0-mlogloss:0.03606	validation_1-mlogloss:0.10894
# [32]	validation_0-mlogloss:0.03419	validation_1-mlogloss:0.10694
# [33]	validation_0-mlogloss:0.03176	validation_1-mlogloss:0.10460
# [34]	validation_0-mlogloss:0.02970	validation_1-mlogloss:0.10331
# [35]	validation_0-mlogloss:0.02769	validation_1-mlogloss:0.10163
# [36]	validation_0-mlogloss:0.02594	validation_1-mlogloss:0.10002
# [37]	validation_0-mlogloss:0.02455	validation_1-mlogloss:0.09858
# [38]	validation_0-mlogloss:0.02315	validation_1-mlogloss:0.09693
# [39]	validation_0-mlogloss:0.02174	validation_1-mlogloss:0.09558
# [40]	validation_0-mlogloss:0.02046	validation_1-mlogloss:0.09415
# [41]	validation_0-mlogloss:0.01921	validation_1-mlogloss:0.09317
# [42]	validation_0-mlogloss:0.01815	validation_1-mlogloss:0.09211
# [43]	validation_0-mlogloss:0.01709	validation_1-mlogloss:0.09108
# [44]	validation_0-mlogloss:0.01599	validation_1-mlogloss:0.08967
# [45]	validation_0-mlogloss:0.01505	validation_1-mlogloss:0.08883
# [46]	validation_0-mlogloss:0.01404	validation_1-mlogloss:0.08755
# [47]	validation_0-mlogloss:0.01332	validation_1-mlogloss:0.08675
# [48]	validation_0-mlogloss:0.01271	validation_1-mlogloss:0.08623
# [49]	validation_0-mlogloss:0.01197	validation_1-mlogloss:0.08498
# [50]	validation_0-mlogloss:0.01132	validation_1-mlogloss:0.08422
# [51]	validation_0-mlogloss:0.01067	validation_1-mlogloss:0.08367
# [52]	validation_0-mlogloss:0.01014	validation_1-mlogloss:0.08281
# [53]	validation_0-mlogloss:0.00960	validation_1-mlogloss:0.08207
# [54]	validation_0-mlogloss:0.00909	validation_1-mlogloss:0.08161
# [55]	validation_0-mlogloss:0.00865	validation_1-mlogloss:0.08077
# [56]	validation_0-mlogloss:0.00823	validation_1-mlogloss:0.08046
# [57]	validation_0-mlogloss:0.00778	validation_1-mlogloss:0.07972
# [58]	validation_0-mlogloss:0.00741	validation_1-mlogloss:0.07925
# [59]	validation_0-mlogloss:0.00712	validation_1-mlogloss:0.07875
# [60]	validation_0-mlogloss:0.00680	validation_1-mlogloss:0.07867
# [61]	validation_0-mlogloss:0.00651	validation_1-mlogloss:0.07805
# [62]	validation_0-mlogloss:0.00621	validation_1-mlogloss:0.07760
# [63]	validation_0-mlogloss:0.00599	validation_1-mlogloss:0.07721
# [64]	validation_0-mlogloss:0.00574	validation_1-mlogloss:0.07666
# [65]	validation_0-mlogloss:0.00547	validation_1-mlogloss:0.07614
# [66]	validation_0-mlogloss:0.00521	validation_1-mlogloss:0.07572
# [67]	validation_0-mlogloss:0.00499	validation_1-mlogloss:0.07524
# [68]	validation_0-mlogloss:0.00481	validation_1-mlogloss:0.07499
# [69]	validation_0-mlogloss:0.00463	validation_1-mlogloss:0.07473
# [70]	validation_0-mlogloss:0.00446	validation_1-mlogloss:0.07459
# [71]	validation_0-mlogloss:0.00429	validation_1-mlogloss:0.07422
# [72]	validation_0-mlogloss:0.00414	validation_1-mlogloss:0.07396
# [73]	validation_0-mlogloss:0.00400	validation_1-mlogloss:0.07369
# [74]	validation_0-mlogloss:0.00387	validation_1-mlogloss:0.07336
# [75]	validation_0-mlogloss:0.00370	validation_1-mlogloss:0.07287
# [76]	validation_0-mlogloss:0.00358	validation_1-mlogloss:0.07266
# [77]	validation_0-mlogloss:0.00347	validation_1-mlogloss:0.07240
# [78]	validation_0-mlogloss:0.00334	validation_1-mlogloss:0.07220
# [79]	validation_0-mlogloss:0.00321	validation_1-mlogloss:0.07219
# [80]	validation_0-mlogloss:0.00312	validation_1-mlogloss:0.07193
# [81]	validation_0-mlogloss:0.00301	validation_1-mlogloss:0.07162
# [82]	validation_0-mlogloss:0.00291	validation_1-mlogloss:0.07135
# [83]	validation_0-mlogloss:0.00280	validation_1-mlogloss:0.07094
# [84]	validation_0-mlogloss:0.00273	validation_1-mlogloss:0.07060
# [85]	validation_0-mlogloss:0.00265	validation_1-mlogloss:0.07035
# [86]	validation_0-mlogloss:0.00257	validation_1-mlogloss:0.07017
# [87]	validation_0-mlogloss:0.00249	validation_1-mlogloss:0.07010
# [88]	validation_0-mlogloss:0.00241	validation_1-mlogloss:0.06993
# [89]	validation_0-mlogloss:0.00235	validation_1-mlogloss:0.06978
# [90]	validation_0-mlogloss:0.00228	validation_1-mlogloss:0.06969
# [91]	validation_0-mlogloss:0.00222	validation_1-mlogloss:0.06971
# [92]	validation_0-mlogloss:0.00215	validation_1-mlogloss:0.06943
# [93]	validation_0-mlogloss:0.00210	validation_1-mlogloss:0.06935
# [94]	validation_0-mlogloss:0.00204	validation_1-mlogloss:0.06923
# [95]	validation_0-mlogloss:0.00198	validation_1-mlogloss:0.06933
# [96]	validation_0-mlogloss:0.00193	validation_1-mlogloss:0.06922
# [97]	validation_0-mlogloss:0.00189	validation_1-mlogloss:0.06921
# [98]	validation_0-mlogloss:0.00184	validation_1-mlogloss:0.06917
# [99]	validation_0-mlogloss:0.00180	validation_1-mlogloss:0.06900
# [100]	validation_0-mlogloss:0.00176	validation_1-mlogloss:0.06890
# [101]	validation_0-mlogloss:0.00171	validation_1-mlogloss:0.06876
# [102]	validation_0-mlogloss:0.00167	validation_1-mlogloss:0.06875
# [103]	validation_0-mlogloss:0.00163	validation_1-mlogloss:0.06869
# [104]	validation_0-mlogloss:0.00159	validation_1-mlogloss:0.06868
# [105]	validation_0-mlogloss:0.00156	validation_1-mlogloss:0.06870
# [106]	validation_0-mlogloss:0.00153	validation_1-mlogloss:0.06872
# [107]	validation_0-mlogloss:0.00150	validation_1-mlogloss:0.06880
# [108]	validation_0-mlogloss:0.00147	validation_1-mlogloss:0.06864
# [109]	validation_0-mlogloss:0.00144	validation_1-mlogloss:0.06855
# done fitting

# %% [markdown]
# #**Performance Analysis**

# %%
plt.figure(figsize=(10, 6))

plt.axvline(x=clf.best_iteration, color='r', linestyle='--', alpha=0.7, label=f'Best iteration = {clf.best_iteration}')

plt.plot(x_axis, results['validation_0']['mlogloss'], label='Training Log Loss')
plt.plot(x_axis, results['validation_1']['mlogloss'], label='Validation Log Loss')
plt.legend()
plt.xlabel('Epochs (Boosting Rounds)')
plt.ylabel('Log Loss')
plt.title('XGBoost Log Loss: Training vs Validation')
plt.grid(True)
plt.show()

print(f"Best model found at iteration: {clf.best_iteration}")

# This automatically uses the best iteration
y_test_pred = clf.predict(X_test)

# Calculate test accuracy
test_acc = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy (using best model): {test_acc:.4f}")
# Out:
# Best model found at iteration: 90
# Test Accuracy (using best model): 0.9775

# %% [markdown]
# #**Generate confusion matrix**
# evaluating on the test set

# %%
cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(
            cm,
            cmap="magma",
            annot=True,
            fmt="d",
            cbar=True,
        )
plt.title('Confusion Matrix: MNIST Digit Classification', fontsize=14)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.show()

print("\nClassification Report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.9895    0.9921    0.9908      1135
#            1     0.9718    0.9690    0.9704      1032
#            2     0.9744    0.9812    0.9778      1010
#            3     0.9836    0.9745    0.9790       982
#            4     0.9819    0.9742    0.9781       892
#            5     0.9822    0.9802    0.9812       958
#            6     0.9755    0.9698    0.9727      1028
#            7     0.9744    0.9774    0.9759       974
#            8     0.9692    0.9653    0.9672      1009
#            9     0.9719    0.9898    0.9808       980
#
#     accuracy                         0.9775     10000
#    macro avg     0.9774    0.9774    0.9774     10000
# weighted avg     0.9775    0.9775    0.9775     10000
